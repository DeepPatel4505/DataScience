# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepPatel4505/DataScience/blob/main/API_data_to_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests

url = "https://imdb236.p.rapidapi.com/imdb/top250-movies"

headers = {
	"x-rapidapi-key": "8f6d0d4220msh91629065b82a7a3p1dab0fjsnc204890d3773",
	"x-rapidapi-host": "imdb236.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

# print(response.json())

# %%
df = pd.DataFrame(response.json())[['primaryTitle','startYear','genres','averageRating','runtimeMinutes']]
df
# Out:
#                  primaryTitle  startYear                     genres  \
# 0    The Shawshank Redemption       1994                    [Drama]
# 1               The Godfather       1972             [Crime, Drama]
# 2             The Dark Knight       2008     [Action, Crime, Drama]
# 3       The Godfather Part II       1974             [Crime, Drama]
# 4                12 Angry Men       1957             [Crime, Drama]
# ..                        ...        ...                        ...
# 245             Groundhog Day       1993   [Comedy, Drama, Fantasy]
# 246                  The Help       2011                    [Drama]
# 247             Amores Perros       2000          [Drama, Thriller]
# 248        Gangs of Wasseypur       2012    [Action, Comedy, Crime]
# 249                   Rebecca       1940  [Drama, Mystery, Romance]
#
#      averageRating  runtimeMinutes
# 0              9.3             142
# 1              9.2             175
# 2              9.0             152
# ...

# %%
df.to_csv('moviesdata.csv')
