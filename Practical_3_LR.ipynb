# %%
#Import required library

# %%
#Read the data using pd.read_csv()

# %%
#Print the columns of the dataframe

# %%
#Checking whether any columns contains null values.

# %%
#checking whether any columns contains NaN values

# %%
#If there is missing value use df.fillna/ scikit learn SimpleImputer to fill it, You con drop raws if it has many null values in it.

# %%
#Divide the data in X(Feature) and Y(target)

# %%
#Feature Selection: Select the important features for the model
#https://www.kaggle.com/code/prashant111/comprehensive-guide-on-feature-selection

# %%
#Convert Categorical data like sex, cities into numerical data using Label encoder or one hot encoder

# %%
#Apply feature scaling min-max/Standard scaler using sklearn.preprocessing

# %%
#Split the dataset into train and test set using train_test_split function

# %%
#create the object of Linear regression and fit the training set X and Y

# %%
#print the interecept and coefficent

# %%
#Evaluate the Linear Regression with Mean Squared Error Metrics
